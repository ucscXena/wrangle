# %% [markdown]
# ## enter sample

# %%
Nof1_sample = raw_input('Enter sample name (e.g. 09-3-B1): ') or "09-3-B1"
print Nof1_sample
# Out:
# Enter sample name (e.g. 09-3-B1):
# 09-3-B1

# %%
import sys
import Nof1_functions
Nof1_hub = "https://itomic.xenahubs.net"
Nof1_dataset = "latestCCI_EXP_G_TPM_log"

# %% [markdown]
# # check sample

# %%
if (Nof1_functions.checkSamples (Nof1_sample, Nof1_hub, Nof1_dataset)):
    sys.exit()
else:
    print "pass"
# Out:
# pass

# %% [markdown]
# # enter gene

# %%
import re
genes = raw_input('Enter a single or a list of gene names (e.g. PTEN or PTEN TP53): ') or "PTEN,TP53"
genes = filter(lambda x: x!='', re.split(';|,| |\n', genes))
print genes
# Out:
# Enter a single or a list of gene names (e.g. PTEN or PTEN TP53): CCND1 CCNE1 CDK4 CDK6 CDKN2A CDKN2C CTLA4 EGFR ESR1 gpNMB JAK2 KRAS LAG-3 LIV-1 MET MTOR MYC MYCN PD-L1 PD-L2 PTEN RB1 ROR1 TP53 TROP2 WEE1
# ['CCND1', 'CCNE1', 'CDK4', 'CDK6', 'CDKN2A', 'CDKN2C', 'CTLA4', 'EGFR', 'ESR1', 'gpNMB', 'JAK2', 'KRAS', 'LAG-3', 'LIV-1', 'MET', 'MTOR', 'MYC', 'MYCN', 'PD-L1', 'PD-L2', 'PTEN', 'RB1', 'ROR1', 'TP53', 'TROP2', 'WEE1']

# %% [markdown]
# # gene name mapping

# %%
genaname_mapping ={
    "CTLA-4" : "CTLA4",
    "LAG-3" : "LAG3",
    "LIV-1" : "SLC39A6",
    "PD-L1" : "CD274",
    "PD-L2" : "PDCD1LG2",
    "TROP2" : "TACSTD2"
}

# %% [markdown]
# # check gene name

# %%
if (Nof1_functions.checkFields(genes, genaname_mapping, Nof1_hub, Nof1_dataset)):
    sys.exit()
else:
    print "pass"
# Out:
# pass

# %% [markdown]
# ## Run - results at the bottom

# %%
import xena_datasetlist

comparison_list = [
    xena_datasetlist.TCGA_BRCA_tumors,
    xena_datasetlist.TCGA_TNBC
]

import itomic_Nof1

for gene in genes:
    itomic_Nof1.itomic_Nof1(Nof1_sample, gene, genaname_mapping[gene], Nof1_hub, Nof1_dataset, comparison_list)

itomic_Nof1.itomic_legend()
# Out:
# Sample:  09-3-B1
# Gene: CCND1
# log2(TPM): 10.1277 TPM: 1118.77
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 17
# [934, 855, 690, 704, 937, 912, 767, 17]
# expression level percentile: 98.54%
# 10-3-B1 934 15.10%
# 10-3-B2 855 22.29%
# 14-1-B2 690 37.31%
# 14-1-B1 704 36.03%
# 15-1-B2 937 14.83%
# 13-1-B1 912 17.11%
# 15-1-B1 767 30.30%
# 09-3-B1 17 98.54%
#
# TCGA_TNBC ( n= 122 ):
# rank: 1
# [67, 54, 38, 39, 67, 59, 42, 1]
# expression level percentile: 100.00%
# 10-3-B1 67 45.90%
# 10-3-B2 54 56.56%
# 14-1-B2 38 69.67%
# 14-1-B1 39 68.85%
# 15-1-B2 67 45.90%
# 13-1-B1 59 52.46%
# 15-1-B1 42 66.39%
# 09-3-B1 1 100.00%
#
# Sample:  09-3-B1
# Gene: CCNE1
# log2(TPM): 1.125 TPM: 2.18
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 712
# [499, 348, 235, 204, 107, 149, 74, 712]
# expression level percentile: 35.30%
# 10-3-B1 499 54.69%
# 10-3-B2 348 68.43%
# 14-1-B2 235 78.71%
# 14-1-B1 204 81.53%
# 15-1-B2 107 90.35%
# 13-1-B1 149 86.53%
# 15-1-B1 74 93.36%
# 09-3-B1 712 35.30%
#
# TCGA_TNBC ( n= 122 ):
# rank: 114
# [110, 99, 89, 85, 55, 68, 32, 114]
# expression level percentile: 7.38%
# 10-3-B1 110 10.66%
# 10-3-B2 99 19.67%
# 14-1-B2 89 27.87%
# 14-1-B1 85 31.15%
# 15-1-B2 55 55.74%
# 13-1-B1 68 45.08%
# 15-1-B1 32 74.59%
# 09-3-B1 114 7.38%
#
# Sample:  09-3-B1
# Gene: CDK4
# log2(TPM): 5.7554 TPM: 54.02
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 1070
# [1092, 1089, 1070, 1062, 1087, 1081, 1022, 1070]
# expression level percentile: 2.73%
# 10-3-B1 1092 0.73%
# 10-3-B2 1089 1.00%
# 14-1-B2 1070 2.73%
# 14-1-B1 1062 3.46%
# 15-1-B2 1087 1.18%
# 13-1-B1 1081 1.73%
# 15-1-B1 1022 7.10%
# 09-3-B1 1070 2.73%
#
# TCGA_TNBC ( n= 122 ):
# rank: 118
# [121, 120, 118, 117, 120, 120, 112, 118]
# expression level percentile: 4.10%
# 10-3-B1 121 1.64%
# 10-3-B2 120 2.46%
# 14-1-B2 118 4.10%
# 14-1-B1 117 4.92%
# 15-1-B2 120 2.46%
# 13-1-B1 120 2.46%
# 15-1-B1 112 9.02%
# 09-3-B1 118 4.10%
#
# Sample:  09-3-B1
# Gene: CDK6
# log2(TPM): 6.869 TPM: 116.89
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 1
# [101, 80, 36, 77, 446, 184, 362, 1]
# expression level percentile: 100.00%
# 10-3-B1 101 90.90%
# 10-3-B2 80 92.81%
# 14-1-B2 36 96.82%
# 14-1-B1 77 93.08%
# 15-1-B2 446 59.51%
# 13-1-B1 184 83.35%
# 15-1-B1 362 67.15%
# 09-3-B1 1 100.00%
#
# TCGA_TNBC ( n= 122 ):
# rank: 1
# [44, 42, 25, 41, 93, 61, 88, 1]
# expression level percentile: 100.00%
# 10-3-B1 44 64.75%
# 10-3-B2 42 66.39%
# 14-1-B2 25 80.33%
# 14-1-B1 41 67.21%
# 15-1-B2 93 24.59%
# 13-1-B1 61 50.82%
# 15-1-B1 88 28.69%
# 09-3-B1 1 100.00%
#
# Sample:  09-3-B1
# Gene: CDKN2A
# log2(TPM): 6.465 TPM: 88.34
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 100
# [254, 170, 130, 119, 45, 119, 4, 100]
# expression level percentile: 90.99%
# 10-3-B1 254 76.98%
# 10-3-B2 170 84.62%
# 14-1-B2 130 88.26%
# 14-1-B1 119 89.26%
# 15-1-B2 45 96.00%
# 13-1-B1 119 89.26%
# 15-1-B1 4 99.73%
# 09-3-B1 100 90.99%
#
# TCGA_TNBC ( n= 122 ):
# rank: 48
# [82, 75, 61, 59, 13, 59, 2, 48]
# expression level percentile: 61.48%
# 10-3-B1 82 33.61%
# 10-3-B2 75 39.34%
# 14-1-B2 61 50.82%
# 14-1-B1 59 52.46%
# 15-1-B2 13 90.16%
# 13-1-B1 59 52.46%
# 15-1-B1 2 99.18%
# 09-3-B1 48 61.48%
#
# Sample:  09-3-B1
# Gene: CDKN2C
# log2(TPM): 5.5289 TPM: 46.17
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 25
# [535, 783, 141, 260, 246, 94, 24, 25]
# expression level percentile: 97.82%
# 10-3-B1 535 51.41%
# 10-3-B2 783 28.84%
# 14-1-B2 141 87.26%
# 14-1-B1 260 76.43%
# 15-1-B2 246 77.71%
# 13-1-B1 94 91.54%
# 15-1-B1 24 97.91%
# 09-3-B1 25 97.82%
#
# TCGA_TNBC ( n= 122 ):
# rank: 12
# [77, 98, 46, 58, 57, 40, 11, 12]
# expression level percentile: 90.98%
# 10-3-B1 77 37.70%
# 10-3-B2 98 20.49%
# 14-1-B2 46 63.11%
# 14-1-B1 58 53.28%
# 15-1-B2 57 54.10%
# 13-1-B1 40 68.03%
# 15-1-B1 11 91.80%
# 09-3-B1 12 90.98%
#
# Sample:  09-3-B1
# Gene: CTLA4
# log2(TPM): 0.9935 TPM: 1.99
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 270
# [6, 7, 17, 21, 295, 350, 305, 270]
# expression level percentile: 75.52%
# 10-3-B1 6 99.55%
# 10-3-B2 7 99.45%
# 14-1-B2 17 98.54%
# 14-1-B1 21 98.18%
# 15-1-B2 295 73.25%
# 13-1-B1 350 68.24%
# 15-1-B1 305 72.34%
# 09-3-B1 270 75.52%
#
# TCGA_TNBC ( n= 122 ):
# rank: 56
# [2, 3, 5, 5, 62, 74, 64, 56]
# expression level percentile: 54.92%
# 10-3-B1 2 99.18%
# 10-3-B2 3 98.36%
# 14-1-B2 5 96.72%
# 14-1-B1 5 96.72%
# 15-1-B2 62 50.00%
# 13-1-B1 74 40.16%
# 15-1-B1 64 48.36%
# 09-3-B1 56 54.92%
#
# Sample:  09-3-B1
# Gene: EGFR
# log2(TPM): 3.154 TPM: 8.90
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 209
# [126, 93, 21, 14, 117, 23, 57, 209]
# expression level percentile: 81.07%
# 10-3-B1 126 88.63%
# 10-3-B2 93 91.63%
# 14-1-B2 21 98.18%
# 14-1-B1 14 98.82%
# 15-1-B2 117 89.44%
# 13-1-B1 23 98.00%
# 15-1-B1 57 94.90%
# 09-3-B1 209 81.07%
#
# TCGA_TNBC ( n= 122 ):
# rank: 70
# [47, 37, 10, 7, 43, 10, 22, 70]
# expression level percentile: 43.44%
# 10-3-B1 47 62.30%
# 10-3-B2 37 70.49%
# 14-1-B2 10 92.62%
# 14-1-B1 7 95.08%
# 15-1-B2 43 65.57%
# 13-1-B1 10 92.62%
# 15-1-B1 22 82.79%
# 09-3-B1 70 43.44%
#
# Sample:  09-3-B1
# Gene: ESR1
# log2(TPM): 0.8488 TPM: 1.80
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 920
# [897, 909, 856, 851, 988, 972, 1050, 920]
# expression level percentile: 16.38%
# 10-3-B1 897 18.47%
# 10-3-B2 909 17.38%
# 14-1-B2 856 22.20%
# 14-1-B1 851 22.66%
# 15-1-B2 988 10.19%
# 13-1-B1 972 11.65%
# 15-1-B1 1050 4.55%
# 09-3-B1 920 16.38%
#
# TCGA_TNBC ( n= 122 ):
# rank: 45
# [34, 38, 18, 16, 70, 64, 97, 45]
# expression level percentile: 63.93%
# 10-3-B1 34 72.95%
# 10-3-B2 38 69.67%
# 14-1-B2 18 86.07%
# 14-1-B1 16 87.70%
# 15-1-B2 70 43.44%
# 13-1-B1 64 48.36%
# 15-1-B1 97 21.31%
# 09-3-B1 45 63.93%
#
# Sample:  09-3-B1
# Gene: gpNMB
# HUGO gene name: GPNMB
# log2(TPM): 6.6524 TPM: 100.59
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 544
# [240, 38, 190, 158, 711, 384, 428, 544]
# expression level percentile: 50.59%
# 10-3-B1 240 78.25%
# 10-3-B2 38 96.63%
# 14-1-B2 190 82.80%
# 14-1-B1 158 85.71%
# 15-1-B2 711 35.40%
# 13-1-B1 384 65.15%
# 15-1-B1 428 61.15%
# 09-3-B1 544 50.59%
#
# TCGA_TNBC ( n= 122 ):
# rank: 65
# [37, 9, 33, 30, 82, 55, 55, 65]
# expression level percentile: 47.54%
# 10-3-B1 37 70.49%
# 10-3-B2 9 93.44%
# 14-1-B2 33 73.77%
# 14-1-B1 30 76.23%
# 15-1-B2 82 33.61%
# 13-1-B1 55 55.74%
# 15-1-B1 55 55.74%
# 09-3-B1 65 47.54%
#
# Sample:  09-3-B1
# Gene: JAK2
# log2(TPM): 3.4129 TPM: 10.65
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 111
# [30, 8, 3, 3, 394, 155, 375, 111]
# expression level percentile: 89.99%
# 10-3-B1 30 97.36%
# 10-3-B2 8 99.36%
# 14-1-B2 3 99.82%
# 14-1-B1 3 99.82%
# 15-1-B2 394 64.24%
# 13-1-B1 155 85.99%
# 15-1-B1 375 65.97%
# 09-3-B1 111 89.99%
#
# TCGA_TNBC ( n= 122 ):
# rank: 16
# [7, 2, 2, 2, 42, 26, 41, 16]
# expression level percentile: 87.70%
# 10-3-B1 7 95.08%
# 10-3-B2 2 99.18%
# 14-1-B2 2 99.18%
# 14-1-B1 2 99.18%
# 15-1-B2 42 66.39%
# 13-1-B1 26 79.51%
# 15-1-B1 41 67.21%
# 09-3-B1 16 87.70%
#
# Sample:  09-3-B1
# Gene: KRAS
# log2(TPM): 8.0473 TPM: 264.53
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 1
# [966, 871, 222, 284, 172, 935, 29, 1]
# expression level percentile: 100.00%
# 10-3-B1 966 12.19%
# 10-3-B2 871 20.84%
# 14-1-B2 222 79.89%
# 14-1-B1 284 74.25%
# 15-1-B2 172 84.44%
# 13-1-B1 935 15.01%
# 15-1-B1 29 97.45%
# 09-3-B1 1 100.00%
#
# TCGA_TNBC ( n= 122 ):
# rank: 1
# [104, 91, 20, 26, 18, 98, 8, 1]
# expression level percentile: 100.00%
# 10-3-B1 104 15.57%
# 10-3-B2 91 26.23%
# 14-1-B2 20 84.43%
# 14-1-B1 26 79.51%
# 15-1-B2 18 86.07%
# 13-1-B1 98 20.49%
# 15-1-B1 8 94.26%
# 09-3-B1 1 100.00%
#
# Sample:  09-3-B1
# Gene: LAG-3
# HUGO gene name: LAG3
# log2(TPM): 2.8681 TPM: 7.30
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 133
# [67, 22, 43, 27, 395, 356, 456, 133]
# expression level percentile: 87.99%
# 10-3-B1 67 93.99%
# 10-3-B2 22 98.09%
# 14-1-B2 43 96.18%
# 14-1-B1 27 97.63%
# 15-1-B2 395 64.15%
# 13-1-B1 356 67.70%
# 15-1-B1 456 58.60%
# 09-3-B1 133 87.99%
#
# TCGA_TNBC ( n= 122 ):
# rank: 30
# [14, 8, 13, 9, 70, 65, 78, 30]
# expression level percentile: 76.23%
# 10-3-B1 14 89.34%
# 10-3-B2 8 94.26%
# 14-1-B2 13 90.16%
# 14-1-B1 9 93.44%
# 15-1-B2 70 43.44%
# 13-1-B1 65 47.54%
# 15-1-B1 78 36.89%
# 09-3-B1 30 76.23%
#
# Sample:  09-3-B1
# Gene: LIV-1
# HUGO gene name: SLC39A6
# log2(TPM): 5.6244 TPM: 49.33
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 938
# [1085, 1082, 926, 973, 1042, 1068, 975, 938]
# expression level percentile: 14.74%
# 10-3-B1 1085 1.36%
# 10-3-B2 1082 1.64%
# 14-1-B2 926 15.83%
# 14-1-B1 973 11.56%
# 15-1-B2 1042 5.28%
# 13-1-B1 1068 2.91%
# 15-1-B1 975 11.37%
# 09-3-B1 938 14.74%
#
# TCGA_TNBC ( n= 122 ):
# rank: 68
# [119, 119, 64, 83, 108, 115, 83, 68]
# expression level percentile: 45.08%
# 10-3-B1 119 3.28%
# 10-3-B2 119 3.28%
# 14-1-B2 64 48.36%
# 14-1-B1 83 32.79%
# 15-1-B2 108 12.30%
# 13-1-B1 115 6.56%
# 15-1-B1 83 32.79%
# 09-3-B1 68 45.08%
#
# Sample:  09-3-B1
# Gene: MET
# log2(TPM): 1.8444 TPM: 3.59
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 511
# [349, 307, 45, 8, 106, 77, 70, 511]
# expression level percentile: 53.59%
# 10-3-B1 349 68.33%
# 10-3-B2 307 72.16%
# 14-1-B2 45 96.00%
# 14-1-B1 8 99.36%
# 15-1-B2 106 90.45%
# 13-1-B1 77 93.08%
# 15-1-B1 70 93.72%
# 09-3-B1 511 53.59%
#
# TCGA_TNBC ( n= 122 ):
# rank: 92
# [79, 76, 23, 6, 45, 36, 34, 92]
# expression level percentile: 25.41%
# 10-3-B1 79 36.07%
# 10-3-B2 76 38.52%
# 14-1-B2 23 81.97%
# 14-1-B1 6 95.90%
# 15-1-B2 45 63.93%
# 13-1-B1 36 71.31%
# 15-1-B1 34 72.95%
# 09-3-B1 92 25.41%
#
# Sample:  09-3-B1
# Gene: MTOR
# log2(TPM): 4.859 TPM: 29.02
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 56
# [280, 233, 170, 163, 481, 755, 26, 56]
# expression level percentile: 95.00%
# 10-3-B1 280 74.61%
# 10-3-B2 233 78.89%
# 14-1-B2 170 84.62%
# 14-1-B1 163 85.26%
# 15-1-B2 481 56.32%
# 13-1-B1 755 31.39%
# 15-1-B1 26 97.73%
# 09-3-B1 56 95.00%
#
# TCGA_TNBC ( n= 122 ):
# rank: 15
# [43, 37, 32, 32, 58, 86, 9, 15]
# expression level percentile: 88.52%
# 10-3-B1 43 65.57%
# 10-3-B2 37 70.49%
# 14-1-B2 32 74.59%
# 14-1-B1 32 74.59%
# 15-1-B2 58 53.28%
# 13-1-B1 86 30.33%
# 15-1-B1 9 93.44%
# 09-3-B1 15 88.52%
#
# Sample:  09-3-B1
# Gene: MYC
# log2(TPM): 7.0143 TPM: 129.27
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 113
# [635, 511, 482, 181, 77, 545, 29, 113]
# expression level percentile: 89.81%
# 10-3-B1 635 42.31%
# 10-3-B2 511 53.59%
# 14-1-B2 482 56.23%
# 14-1-B1 181 83.62%
# 15-1-B2 77 93.08%
# 13-1-B1 545 50.50%
# 15-1-B1 29 97.45%
# 09-3-B1 113 89.81%
#
# TCGA_TNBC ( n= 122 ):
# rank: 24
# [89, 83, 79, 35, 21, 85, 9, 24]
# expression level percentile: 81.15%
# 10-3-B1 89 27.87%
# 10-3-B2 83 32.79%
# 14-1-B2 79 36.07%
# 14-1-B1 35 72.13%
# 15-1-B2 21 83.61%
# 13-1-B1 85 31.15%
# 15-1-B1 9 93.44%
# 09-3-B1 24 81.15%
#
# Sample:  09-3-B1
# Gene: MYCN
# log2(TPM): -0.0877 TPM: 0.94
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 338
# [222, 296, 299, 211, 715, 101, 452, 338]
# expression level percentile: 69.34%
# 10-3-B1 222 79.89%
# 10-3-B2 296 73.16%
# 14-1-B2 299 72.88%
# 14-1-B1 211 80.89%
# 15-1-B2 715 35.03%
# 13-1-B1 101 90.90%
# 15-1-B1 452 58.96%
# 09-3-B1 338 69.34%
#
# TCGA_TNBC ( n= 122 ):
# rank: 54
# [42, 48, 49, 40, 98, 22, 73, 54]
# expression level percentile: 56.56%
# 10-3-B1 42 66.39%
# 10-3-B2 48 61.48%
# 14-1-B2 49 60.66%
# 14-1-B1 40 68.03%
# 15-1-B2 98 20.49%
# 13-1-B1 22 82.79%
# 15-1-B1 73 40.98%
# 09-3-B1 54 56.56%
#
# Sample:  09-3-B1
# Gene: PD-L1
# HUGO gene name: CD274
# log2(TPM): 1.5165 TPM: 2.86
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 241
# [32, 4, 4, 5, 571, 187, 702, 241]
# expression level percentile: 78.16%
# 10-3-B1 32 97.18%
# 10-3-B2 4 99.73%
# 14-1-B2 4 99.73%
# 14-1-B1 5 99.64%
# 15-1-B2 571 48.13%
# 13-1-B1 187 83.08%
# 15-1-B1 702 36.21%
# 09-3-B1 241 78.16%
#
# TCGA_TNBC ( n= 122 ):
# rank: 49
# [11, 3, 3, 3, 79, 43, 88, 49]
# expression level percentile: 60.66%
# 10-3-B1 11 91.80%
# 10-3-B2 3 98.36%
# 14-1-B2 3 98.36%
# 14-1-B1 3 98.36%
# 15-1-B2 79 36.07%
# 13-1-B1 43 65.57%
# 15-1-B1 88 28.69%
# 09-3-B1 49 60.66%
#
# Sample:  09-3-B1
# Gene: PD-L2
# HUGO gene name: PDCD1LG2
# log2(TPM): 2.3649 TPM: 5.15
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 100
# [30, 3, 2, 3, 501, 217, 569, 100]
# expression level percentile: 90.99%
# 10-3-B1 30 97.36%
# 10-3-B2 3 99.82%
# 14-1-B2 2 99.91%
# 14-1-B1 3 99.82%
# 15-1-B2 501 54.50%
# 13-1-B1 217 80.35%
# 15-1-B1 569 48.32%
# 09-3-B1 100 90.99%
#
# TCGA_TNBC ( n= 122 ):
# rank: 26
# [10, 2, 2, 2, 80, 51, 86, 26]
# expression level percentile: 79.51%
# 10-3-B1 10 92.62%
# 10-3-B2 2 99.18%
# 14-1-B2 2 99.18%
# 14-1-B1 2 99.18%
# 15-1-B2 80 35.25%
# 13-1-B1 51 59.02%
# 15-1-B1 86 30.33%
# 09-3-B1 26 79.51%
#
# Sample:  09-3-B1
# Gene: PTEN
# log2(TPM): 3.7072 TPM: 13.06
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 1025
# [957, 978, 633, 709, 839, 978, 340, 1025]
# expression level percentile: 6.82%
# 10-3-B1 957 13.01%
# 10-3-B2 978 11.10%
# 14-1-B2 633 42.49%
# 14-1-B1 709 35.58%
# 15-1-B2 839 23.75%
# 13-1-B1 978 11.10%
# 15-1-B1 340 69.15%
# 09-3-B1 1025 6.82%
#
# TCGA_TNBC ( n= 122 ):
# rank: 100
# [93, 94, 57, 70, 83, 94, 26, 100]
# expression level percentile: 18.85%
# 10-3-B1 93 24.59%
# 10-3-B2 94 23.77%
# 14-1-B2 57 54.10%
# 14-1-B1 70 43.44%
# 15-1-B2 83 32.79%
# 13-1-B1 94 23.77%
# 15-1-B1 26 79.51%
# 09-3-B1 100 18.85%
#
# Sample:  09-3-B1
# Gene: RB1
# log2(TPM): 4.6479 TPM: 25.07
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 346
# [826, 716, 361, 545, 612, 900, 307, 346]
# expression level percentile: 68.61%
# 10-3-B1 826 24.93%
# 10-3-B2 716 34.94%
# 14-1-B2 361 67.24%
# 14-1-B1 545 50.50%
# 15-1-B2 612 44.40%
# 13-1-B1 900 18.20%
# 15-1-B1 307 72.16%
# 09-3-B1 346 68.61%
#
# TCGA_TNBC ( n= 122 ):
# rank: 22
# [55, 42, 23, 31, 37, 65, 19, 22]
# expression level percentile: 82.79%
# 10-3-B1 55 55.74%
# 10-3-B2 42 66.39%
# 14-1-B2 23 81.97%
# 14-1-B1 31 75.41%
# 15-1-B2 37 70.49%
# 13-1-B1 65 47.54%
# 15-1-B1 19 85.25%
# 09-3-B1 22 82.79%
#
# Sample:  09-3-B1
# Gene: ROR1
# log2(TPM): 3.0056 TPM: 8.03
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 22
# [139, 151, 29, 12, 12, 85, 4, 22]
# expression level percentile: 98.09%
# 10-3-B1 139 87.44%
# 10-3-B2 151 86.35%
# 14-1-B2 29 97.45%
# 14-1-B1 12 99.00%
# 15-1-B2 12 99.00%
# 13-1-B1 85 92.36%
# 15-1-B1 4 99.73%
# 09-3-B1 22 98.09%
#
# TCGA_TNBC ( n= 122 ):
# rank: 10
# [45, 46, 14, 6, 6, 33, 3, 10]
# expression level percentile: 92.62%
# 10-3-B1 45 63.93%
# 10-3-B2 46 63.11%
# 14-1-B2 14 89.34%
# 14-1-B1 6 95.90%
# 15-1-B2 6 95.90%
# 13-1-B1 33 73.77%
# 15-1-B1 3 98.36%
# 09-3-B1 10 92.62%
#
# Sample:  09-3-B1
# Gene: TP53
# log2(TPM): 7.4422 TPM: 173.91
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 2
# [603, 802, 657, 576, 250, 172, 49, 2]
# expression level percentile: 99.91%
# 10-3-B1 603 45.22%
# 10-3-B2 802 27.12%
# 14-1-B2 657 40.31%
# 14-1-B1 576 47.68%
# 15-1-B2 250 77.34%
# 13-1-B1 172 84.44%
# 15-1-B1 49 95.63%
# 09-3-B1 2 99.91%
#
# TCGA_TNBC ( n= 122 ):
# rank: 2
# [66, 71, 68, 63, 48, 41, 20, 2]
# expression level percentile: 99.18%
# 10-3-B1 66 46.72%
# 10-3-B2 71 42.62%
# 14-1-B2 68 45.08%
# 14-1-B1 63 49.18%
# 15-1-B2 48 61.48%
# 13-1-B1 41 67.21%
# 15-1-B1 20 84.43%
# 09-3-B1 2 99.18%
#
# Sample:  09-3-B1
# Gene: TROP2
# HUGO gene name: TACSTD2
# log2(TPM): 0.6608 TPM: 1.58
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 1096
# [1047, 625, 949, 953, 690, 951, 981, 1096]
# expression level percentile: 0.36%
# 10-3-B1 1047 4.82%
# 10-3-B2 625 43.22%
# 14-1-B2 949 13.74%
# 14-1-B1 953 13.38%
# 15-1-B2 690 37.31%
# 13-1-B1 951 13.56%
# 15-1-B1 981 10.83%
# 09-3-B1 1096 0.36%
#
# TCGA_TNBC ( n= 122 ):
# rank: 123
# [113, 78, 106, 107, 80, 107, 109, 123]
# expression level percentile: 0.00%
# 10-3-B1 113 8.20%
# 10-3-B2 78 36.89%
# 14-1-B2 106 13.93%
# 14-1-B1 107 13.11%
# 15-1-B2 80 35.25%
# 13-1-B1 107 13.11%
# 15-1-B1 109 11.48%
# 09-3-B1 123 0.00%
#
# Sample:  09-3-B1
# Gene: WEE1
# log2(TPM): 3.7518 TPM: 13.47
#
# TCGA_BRCA_tumors ( n= 1099 ):
# rank: 968
# [1044, 1050, 993, 887, 717, 602, 641, 968]
# expression level percentile: 12.01%
# 10-3-B1 1044 5.10%
# 10-3-B2 1050 4.55%
# 14-1-B2 993 9.74%
# 14-1-B1 887 19.38%
# 15-1-B2 717 34.85%
# 13-1-B1 602 45.31%
# 15-1-B1 641 41.77%
# 09-3-B1 968 12.01%
#
# TCGA_TNBC ( n= 122 ):
# rank: 106
# [113, 113, 109, 98, 80, 64, 67, 106]
# expression level percentile: 13.93%
# 10-3-B1 113 8.20%
# 10-3-B2 113 8.20%
# 14-1-B2 109 11.48%
# 14-1-B1 98 20.49%
# 15-1-B2 80 35.25%
# 13-1-B1 64 48.36%
# 15-1-B1 67 45.90%
# 09-3-B1 106 13.93%
#
# Expression values are sorted from high to low.
# Low rank means high expression.
# expression level percentile is the percentile of samples has lower expression than sample of interest.
# High expression level percentile means higher expression.
